# %%
import FlowCal

s = FlowCal.io.FCSData('04-blank-A2-1.fcs')
print(s.shape)
# Out:
# (137793, 26)

# %%
print(s.channels)
# Out:
# ('FSC-H', 'FSC-A', 'SSC-H', 'SSC-A', 'FL1-H', 'FL1-A', 'FL2-H', 'FL2-A', 'FL3-H', 'FL3-A', 'FL4-H', 'FL4-A', 'FL5-H', 'FL5-A', 'FL6-H', 'FL6-A', 'FL7-H', 'FL7-A', 'FL8-H', 'FL8-A', 'FL9-H', 'FL9-A', 'FL10-H', 'FL10-A', 'FSC-Width', 'Time')

# %%
import matplotlib.pyplot as plt
plt.hist(s[:, 'FL1-H'], bins=100)
plt.show()

# %%
s_transformed = FlowCal.transform.to_rfi(s, channels='FL1-H')
s_transformed
# Out:
# FCSData([[ 1.08947998e+04,  1.85655000e+04,  1.25880000e+04, ...,
#            7.59000015e+01,  1.74601025e+03,  3.98000000e+02],
#          [ 1.13407002e+04,  2.23380005e+03,  6.90400000e+03, ...,
#            1.41699997e+02,  2.01710663e+02,  7.18000000e+02],
#          [ 1.20959004e+04,  7.85370020e+03,  1.31537998e+04, ...,
#           -1.05099998e+02,  6.65244202e+02,  1.26800000e+03],
#          ...,
#          [ 2.38091992e+04,  2.06908008e+04,  2.78390000e+04, ...,
#            3.87999992e+01,  8.89892456e+02,  2.99996000e+06],
#          [ 1.20502998e+04,  6.95900024e+02,  1.22862998e+04, ...,
#           -6.90000000e+01,  5.90703850e+01,  2.99997100e+06],
#          [ 1.05080000e+04,  1.12082002e+04,  8.84450000e+03, ...,
#            6.76999969e+01,  1.09258191e+03,  2.99998100e+06]])

# %%
import numpy as np
bins = np.logspace(0, 4, 100)
plt.hist(s_transformed[:, 'FL1-H'], bins=bins)
plt.xscale('log')
plt.show()

# %%
s = FlowCal.io.FCSData('02-blank-A2-4.fcs')
s = FlowCal.transform.to_rfi(s)

FlowCal.plot.hist1d(s, channel='FL1-H')
plt.show()

# %%
FlowCal.plot.hist1d(s, channel='FL1-H', xscale='log', bins=1024)
plt.show()

# %%
filenames = ['02-blank-A2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
#d = [FlowCal.transform.to_rfi(di) for di in d]
print(d)
print(type(d[0]))
print(d[0])
print(dir(d[0]))
print(d[0].tolist())
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()
# Out:
# [FCSData([[ 1.0809600e+04,  1.3545500e+04,  1.0418400e+04, ...,
#           -7.5400002e+01,  1.2833160e+03,  8.1819000e+04],
#          [ 1.3075400e+04,  4.2512002e+03,  1.1458000e+04, ...,
#           -1.6700001e+01,  3.3296451e+02,  8.2757000e+04],
#          [ 1.4686000e+04,  1.2945100e+04,  7.8331001e+03, ...,
#            7.4400002e+01,  9.0294061e+02,  9.4306000e+04],
#          ...,
#          [ 1.1164100e+04,  1.2743900e+04,  1.9509900e+04, ...,
#           -4.7900002e+01,  1.1692501e+03,  2.9999460e+06],
#          [ 1.2571400e+04,  1.3722000e+04,  1.2295200e+04, ...,
#            2.3200001e+01,  1.1180242e+03,  2.9999740e+06],
#          [ 1.4642600e+04,  1.0874300e+04,  3.2465000e+03, ...,
#            1.1410000e+02,  7.6058582e+02,  2.9999830e+06]], dtype=float32), FCSData([[ 1.5624000e+04,  1.2474000e+04,  1.4334800e+04, ...,
#            3.6799999e+01,  8.1754840e+02,  2.1220000e+03],
#          [ 1.0024500e+04,  5.5255000e+03,  1.2413200e+04, ...,
#           -1.8100000e+01,  5.6445648e+02,  2.8180000e+03],
#          [ 1.3426600e+04,  7.7607002e+03,  1.2125300e+04, ...,
#            5.2500000e+01,  5.9194281e+02,  4.0240000e+03],
#          ...,
#          [ 1.2114100e+04,  1.0306900e+04,  1.5380000e+04, ...,
#           -1.5889999e+02,  8.7131305e+02,  2.9998940e+06],
#          [ 1.6220800e+04,  1.6595199e+04,  2.0165301e+04, ...,
#            2.5200001e+01,  1.0479014e+03,  2.9999340e+06],
#          [ 1.0024900e+04,  8.7195000e+03,  9.7642002e+03, ...,
#            1.0690000e+02,  8.9073901e+02,  2.9999410e+06]], dtype=float32), FCSData([[ 1.8665699e+04,  9.0450996e+03,  1.0289200e+04, ...,
#            1.0770000e+02,  4.9622632e+02,  1.3000000e+01],
#          [ 1.1975000e+04,  5.8643999e+03,  9.1850996e+03, ...,
#           -1.1440000e+02,  5.0173264e+02,  2.7000000e+01],
#          [ 1.2805900e+04,  9.7432002e+03,  1.2309300e+04, ...,
#           -1.2130000e+02,  7.7944000e+02,  3.2000000e+01],
#          ...,
#          [ 1.2989300e+04,  2.7790000e+03,  1.1795100e+04, ...,
#            8.5199997e+01,  2.1916943e+02,  2.9999370e+06],
#          [ 1.6414900e+04,  5.6292998e+03,  1.3193700e+04, ...,
#            2.3850000e+02,  3.5129791e+02,  2.9999490e+06],
#          [ 1.4927500e+04,  1.0954200e+04,  7.1667998e+03, ...,
#            7.7500000e+01,  7.5176837e+02,  2.9999920e+06]], dtype=float32), FCSData([[ 1.6095400e+04,  7.2428999e+03,  9.3902998e+03, ...,
#           -1.6410001e+02,  4.6098459e+02,  0.0000000e+00],
#          [ 1.2924200e+04,  9.8897998e+03,  1.2594700e+04, ...,
#            6.4000001e+00,  7.8377216e+02,  3.2000000e+01],
#          [ 1.1885500e+04,  2.1780400e+04,  1.4408200e+04, ...,
#            1.9080000e+02,  1.8773334e+03,  3.4000000e+01],
#          ...,
#          [ 1.3238500e+04,  5.9567002e+03,  1.0482700e+04, ...,
#           -3.6500000e+01,  4.6092383e+02,  2.9999760e+06],
#          [ 1.6716699e+04,  7.5136001e+03,  1.1582400e+04, ...,
#            6.2000000e+01,  4.6037723e+02,  2.9999820e+06],
#          [ 1.0113700e+04,  8.8372002e+03,  1.2195200e+04, ...,
#            7.4400002e+01,  8.9488605e+02,  2.9999950e+06]], dtype=float32)]
# <class 'FlowCal.io.FCSData'>
# 02-blank-A3-1.fcs
# ['T', '__abs__', '__add__', '__and__', '__array__', '__array_finalize__', '__array_function__', '__array_interface__', '__array_prepare__', '__array_priority__', '__array_struct__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__class_getitem__', '__complex__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__xor__', '_acquisition_end_time', '_acquisition_start_time', '_amplification_type', '_amplifier_gain', '_analysis', '_channel_labels', '_channels', '_data_type', '_detector_voltage', '_infile', '_name_to_index', '_parse_date_string', '_parse_time_string', '_range', '_resolution', '_text', '_time_step', 'acquisition_end_time', 'acquisition_start_time', 'acquisition_time', 'all', 'amplification_type', 'amplifier_gain', 'analysis', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'astype', 'base', 'byteswap', 'channel_labels', 'channels', 'choose', 'clip', 'compress', 'conj', 'conjugate', 'copy', 'ctypes', 'cumprod', 'cumsum', 'data', 'data_type', 'detector_voltage', 'diagonal', 'dot', 'dtype', 'dump', 'dumps', 'fill', 'flags', 'flat', 'flatten', 'getfield', 'hist_bins', 'imag', 'infile', 'item', 'itemset', 'itemsize', 'max', 'mean', 'min', 'nbytes', 'ndim', 'newbyteorder', 'nonzero', 'partition', 'prod', 'ptp', 'put', 'range', 'ravel', 'real', 'repeat', 'reshape', 'resize', 'resolution', 'round', 'searchsorted', 'setfield', 'setflags', 'shape', 'size', 'sort', 'squeeze', 'std', 'strides', 'sum', 'swapaxes', 'take', 'text', 'time_step', 'tobytes', 'tofile', 'tolist', 'tostring', 'trace', 'transpose', 'var', 'view']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
filenames = ['02-blank-A4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-A11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-C11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-E11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G2-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G3-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G4-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G5-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G6-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G7-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G8-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G9-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G10-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()

# %%
filenames = ['02-blank-G11-{:01d}.fcs'.format(i + 1) for i in range(4)]
d = [FlowCal.io.FCSData(filename) for filename in filenames]
d = [FlowCal.transform.to_rfi(di) for di in d]
FlowCal.plot.hist1d(d, channel='FL1-H', alpha=0.7, bins=128)
plt.legend(filenames, loc='upper left')
plt.show()
